# %%
#import the packages
import math
import pandas as pd
import numpy as np
import os
from pandas import DataFrame
from sklearn.cluster import KMeans
from sklearn import preprocessing
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
style.use('ggplot')
import matplotlib.pylab as plt

from matplotlib.pylab import rcParams
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
import sklearn
from sklearn.metrics import mean_squared_error

# %%
#check directory
cwd = os.getcwd()
cwd

bycountry= pd.read_csv("GlobalLandTemperaturesByCountry.csv", index_col=None)
bycountry.head(10)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty Country
# 0  1743-11-01               4.384                          2.294   Åland
# 1  1743-12-01                 NaN                            NaN   Åland
# 2  1744-01-01                 NaN                            NaN   Åland
# 3  1744-02-01                 NaN                            NaN   Åland
# 4  1744-03-01                 NaN                            NaN   Åland
# 5  1744-04-01               1.530                          4.680   Åland
# 6  1744-05-01               6.702                          1.789   Åland
# 7  1744-06-01              11.609                          1.577   Åland
# 8  1744-07-01              15.342                          1.410   Åland
# 9  1744-08-01                 NaN                            NaN   Åland

# %%
#take a look at Nepal
nepal=bycountry.loc[bycountry['Country'] == "Nepal"]
type(nepal)
nepal.infer_objects()
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty Country
# 361462  1796-01-01               5.934                          2.235   Nepal
# 361463  1796-02-01               7.780                          1.645   Nepal
# 361464  1796-03-01              10.935                          2.241   Nepal
# 361465  1796-04-01              16.477                          1.737   Nepal
# 361466  1796-05-01              20.338                          1.663   Nepal
# 361467  1796-06-01              21.781                          2.825   Nepal
# 361468  1796-07-01              21.020                          2.269   Nepal
# 361469  1796-08-01              21.276                          2.867   Nepal
# 361470  1796-09-01              19.257                          3.167   Nepal
# 361471  1796-10-01              15.819                          1.627   Nepal
# 361472  1796-11-01              10.664                          2.624   Nepal
# 361473  1796-12-01               4.654                          3.445   Nepal
# 361474  1797-01-01                 NaN                            NaN   Nepal
# 361475  1797-02-01                 NaN                            NaN   Nepal
# 361476  1797-03-01              11.440                          1.882   Nepal
# 361477  1797-04-01              15.505                          2.603   Nepal
# 361478  1797-05-01              19.369                          2.165   Nepal
# 361479  1797-06-01              21.937                          2.081   Nepal
# 361480  1797-07-01              20.783                          2.239   Nepal
# 361481  1797-08-01              20.887                          2.138   Nepal
# 361482  1797-09-01              19.328                          2.904   Nepal
# 361483  1797-10-01              15.374                          2.103   Nepal
# 361484  1797-11-01               9.412                          1.964   Nepal
# 361485  1797-12-01               6.509                          2.525   Nepal
# 361486  1798-01-01               6.205                          1.816   Nepal
# 361487  1798-02-01               7.932                          1.874   Nepal
# 361488  1798-03-01              13.297                          1.742   Nepal
# 361489  1798-04-01                 NaN                            NaN   Nepal
# 361490  1798-05-01                 NaN                            NaN   Nepal
# 361491  1798-06-01              21.353                          2.037   Nepal
# ...            ...                 ...                            ...     ...
# 364045  2011-04-01              16.627                          0.296   Nepal
# 364046  2011-05-01              20.141                          0.408   Nepal
# 364047  2011-06-01              20.840                          0.426   Nepal
# 364048  2011-07-01              20.979                          0.398   Nepal
# 364049  2011-08-01              20.678                          0.490   Nepal
# 364050  2011-09-01              19.928                          0.239   Nepal
# 364051  2011-10-01              16.295                          0.623   Nepal
# 364052  2011-11-01              12.428                          0.449   Nepal
# 364053  2011-12-01               7.670                          0.827   Nepal
# 364054  2012-01-01               5.208                          0.588   Nepal
# 364055  2012-02-01               8.964                          0.460   Nepal
# 364056  2012-03-01              13.124                          0.403   Nepal
# 364057  2012-04-01              17.260                          0.477   Nepal
# 364058  2012-05-01              21.106                          0.417   Nepal
# 364059  2012-06-01              23.440                          0.481   Nepal
# 364060  2012-07-01              20.975                          0.739   Nepal
# 364061  2012-08-01              21.051                          0.458   Nepal
# 364062  2012-09-01              19.966                          0.459   Nepal
# 364063  2012-10-01              15.500                          0.477   Nepal
# 364064  2012-11-01              10.748                          0.494   Nepal
# 364065  2012-12-01               7.696                          0.444   Nepal
# 364066  2013-01-01               4.628                          0.751   Nepal
# 364067  2013-02-01               8.357                          0.839   Nepal
# 364068  2013-03-01              13.114                          0.569   Nepal
# 364069  2013-04-01              16.893                          0.423   Nepal
# 364070  2013-05-01              20.691                          0.446   Nepal
# 364071  2013-06-01              21.375                          0.452   Nepal
# 364072  2013-07-01              21.367                          0.300   Nepal
# 364073  2013-08-01              21.185                          0.442   Nepal
# 364074  2013-09-01                 NaN                            NaN   Nepal
#
# [2613 rows x 4 columns]

# %%
temp=nepal['AverageTemperature']
temp=temp.dropna(how='any')

# %%
#pre-processing
scale=preprocessing.scale(temp)
plt.plot(scale)
scale
# Out:
# array([-1.55599873, -1.23229229, -0.67904538, ...,  1.15166708,
#         1.15026424,  1.11834952])

# %%
#let's get a small sample to see
scale
df=DataFrame(scale)
sample=df[0:500]
sample
plt.plot(sample)
#now we can see the patterns

# %%
#now we can see the patterns

X=sample.values
X
train, test = X[0:-100], X[-100:]
train
test
# Out:
# array([[ 0.10847662],
#        [ 0.5978941 ],
#        [ 0.86057679],
#        [ 0.81743931],
#        [ 0.69574252],
#        [ 0.38097922],
#        [-0.1098411 ],
#        [-1.04851962],
#        [-1.74818847],
#        [-1.72188513],
#        [-1.33294641],
#        [-0.49755233],
#        [ 0.21579425],
#        [ 0.77079472],
#        [ 1.06977602],
#        [ 0.9861314 ],
#        [ 0.87811235],
#        [ 0.60543439],
#        [ 0.08234864],
#        [-0.87421616],
#        [-1.37450568],
#        [-1.58633525],
#        [-1.18810268],
#        [-0.66449086],
#        [ 0.02237702],
#        [ 0.65646287],
#        [ 0.94755316],
#        [ 0.98052002],
#        [ 0.87162419],
#        [ 0.65453396],
#        [-0.01129125],
#        [-0.81652417],
#        [-1.36486113],
#        [-2.08872904],
#        [-1.44464792],
#        [-0.68079893],
#        [ 0.29505498],
#        [ 0.69311219],
#        [ 1.07345848],
#        [ 1.11449169],
#        [ 0.93019296],
#        [ 0.62279459],
#        [ 0.08550504],
#        [-0.74269946],
#        [-1.48340151],
#        [-1.61053432],
#        [-1.0885007 ],
#        [-0.83160475],
#        [ 0.28067582],
#        [ 0.75273309],
#        [ 0.99016457],
#        [ 1.10467178],
#        [ 0.97122617],
#        [ 0.55352913],
#        [ 0.04043865],
#        [-0.98889872],
#        [-1.71381877],
#        [-1.47252946],
#        [-1.16144863],
#        [-0.51210685],
#        [ 0.30540096],
#        [ 0.79990375],
#        [ 1.01681862],
#        [ 1.17604151],
#        [ 0.8672403 ],
#        [ 0.57492251],
#        [-0.04583631],
#        [-0.8456332 ],
#        [-1.49988494],
#        [-1.62386135],
#        [-1.24088472],
#        [-0.66186053],
#        [ 0.10742449],
#        [ 0.78552459],
#        [ 1.08468124],
#        [ 1.09765756],
#        [ 0.93405078],
#        [ 0.63366664],
#        [ 0.02728698],
#        [-0.74322553],
#        [-1.51005556],
#        [-1.64385189],
#        [-1.20037757],
#        [-0.41566127],
#        [ 0.32889861],
#        [ 0.85110758],
#        [ 0.96315981],
#        [ 1.01050582],
#        [ 0.85724503],
#        [ 0.53336324],
#        [-0.040751  ],
#        [-0.80617819],
#        [-1.30997482],
#        [-1.52390866],
#        [-1.05781347],
#        [-0.52946705],
#        [ 0.22473738],
#        [ 0.71871411],
#        [ 1.0192736 ],
#        [ 1.08468124]])

# %%
# walk-forward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
	# make prediction
	predictions.append(history[-1])
	# observation
	history.append(test[i])
# report performance
rmse = math.sqrt(mean_squared_error(test, predictions))
print('RMSE: %.3f' % rmse)
# line plot of observed vs predicted
pyplot.plot(test)
pyplot.plot(predictions)
pyplot.show()
rmse
# Out:
# RMSE: 0.530
# 0.5302435957527816

# %%
#a smaller sample of 50
sample2=sample[0:50]
X2=sample2.values
X2
train2, test2 = X2[0:-10], X2[-10:]
train2
test2
# Out:
# array([[ 0.81638717],
#        [ 0.2629649 ],
#        [-0.68342927],
#        [-1.51443945],
#        [-1.56862433],
#        [-1.1134012 ],
#        [-0.57383202],
#        [ 0.51267128],
#        [ 0.8344488 ],
#        [ 1.16955335]])

# %%
# walk-forward validation
history2 = [x for x in train2]
predictions2 = list()
for i in range(len(test2)):
	# make prediction2
	predictions2.append(history2[-1])
	# observation
	history2.append(test2[i])
# report performance
rmse2 = math.sqrt(mean_squared_error(test2, predictions2))
print('RMSE: %.3f' % rmse2)
# line plot of observed vs predicted
pyplot.plot(test2)
pyplot.plot(predictions2)
pyplot.show()
rmse2
# Out:
# RMSE: 0.622
# 0.6220490938792729

# %%
pyplot.plot(test2)
pyplot.plot(predictions2)
rcParams['figure.figsize'] = 20, 10
pyplot.show()

# %%
## Countries with the highest temperature differences¶
## Now let's look at the top 15 countries with highest temperature differences. Temperature difference is the difference between the maximum and minimum temperature value.

# %%
tempByCountry = pd.read_csv('GlobalLandTemperaturesByCountry.csv')
countries = tempByCountry['Country'].unique()

# %%
import seaborn as sns

# %%
max_min_list = []

# getting max and min temperatures
for country in countries:
    curr_temps = tempByCountry[tempByCountry['Country'] == country]['AverageTemperature']
    max_min_list.append((curr_temps.max(), curr_temps.min()))
    
# NaN cleaning
res_max_min_list = []
res_countries = []

for i in range(len(max_min_list)):
    if not np.isnan(max_min_list[i][0]):
        res_max_min_list.append(max_min_list[i])
        res_countries.append(countries[i])

# calculating the differences        
differences = []

for tpl in res_max_min_list:
    differences.append(tpl[0] - tpl[1])
    
# sorting the result
differences, res_countries = (list(x) for x in zip(*sorted(zip(differences, res_countries), key=lambda pair: pair[0], reverse=True)))

# ploting the chart
f, ax = plt.subplots(figsize=(8, 8))
sns.barplot(x=differences[:20], y=res_countries[:20], palette=sns.color_palette("coolwarm", 25), ax=ax)

texts = ax.set(ylabel="", xlabel="Temperature difference", title="Countries with the highest temperature differences")

# %%
#reading the file and collecting only the timestamp and the year 
dframe= pd.read_csv('GlobalLandTemperaturesByMajorCity.csv')
df_ny = dframe[dframe['City']=='New York']
df_ny= df_ny.iloc[:, :2]
df_ny.head(10)
# Out:
#                 dt  AverageTemperature
# 169769  1743-11-01               3.264
# 169770  1743-12-01                 NaN
# 169771  1744-01-01                 NaN
# 169772  1744-02-01                 NaN
# 169773  1744-03-01                 NaN
# 169774  1744-04-01               9.788
# 169775  1744-05-01              15.708
# 169776  1744-06-01              21.210
# 169777  1744-07-01              22.207
# 169778  1744-08-01                 NaN

# %%
#selecting only the year from the time stamp and grouping the data by mean temperature of each year
a = df_ny['dt'].apply(lambda x: int(x[0:4]))
grouped = df_ny.groupby(a).mean()
grouped.head(10)
# Out:
#       AverageTemperature
# dt
# 1743            3.264000
# 1744           11.660375
# 1745            1.134500
# 1746                 NaN
# 1747                 NaN
# 1748                 NaN
# 1749                 NaN
# 1750           10.071455
# 1751           10.794625
# 1752            2.814500

# %%
#plotting the data
plt.plot(grouped['AverageTemperature'])
plt.show()
#As we can see there are several blank spaces due to the Nan's blocks in the data

# %%
df_kath['AverageTemperature'] = df_kath['AverageTemperature'].fillna(method = 'ffill')
grouped = df_kath.groupby(a).mean()
plt.plot(grouped['AverageTemperature'])
plt.xlabel('year')
plt.ylabel('temperature in degree celsius')
plt.title('New York avreage temperature verus year')
plt.show()

# %%
#modelling the data to obtain future values
from sklearn.linear_model import LinearRegression as LinReg

# %%
#reshaping the index of 'grouped'i.e years
x= grouped.index.values.reshape(-1,1)
#obtaining values of temperature
y = grouped['AverageTemperature'].values

# %%
#Using linear regression and finding accuracy of our prediction
reg = LinReg()
reg.fit(x,y)
y_preds = reg.predict(x)
Accuracy = str(reg.score(x,y))
print(Accuracy)
# Out:
# 0.24223324942541424

# %%
#plotting data along with regression
plt.scatter(x=x, y=y_preds)
plt.scatter(x=x,y=y, c='r')
plt.ylabel('Average Temperature in degree celsius')
plt.xlabel('year')
plt.show()

# %%
#finding future values of temperature
reg.predict(2048)
# Out:
# array([10.70528732])

# %%
reg.predict(2020)
# Out:
# array([10.4957697])

# %%
#A quick chart of the five hottest cities in 2010
dd = dframe[pd.DatetimeIndex(dframe['dt']).year == 2010][['City', 'Country', 'AverageTemperature']].groupby(['City', 'Country']).mean().sort_values('AverageTemperature',ascending=False).head(n=10)
dd
# Out:
#                                AverageTemperature
# City             Country
# Umm Durman       Sudan                  30.730167
# Jiddah           Saudi Arabia           29.422083
# Madras           India                  29.047333
# Bangkok          Thailand               28.536917
# Ho Chi Minh City Vietnam                28.281750
# Rangoon          Burma                  28.216417
# Fortaleza        Brazil                 28.179167
# Mogadishu        Somalia                28.025583
# Ahmadabad        India                  28.017833
# Lagos            Nigeria                27.793333
